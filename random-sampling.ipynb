# %% [markdown]
# # Random sampling

# %%
from tally import Composition

for i in range(20):
    composition = Composition.random()
    composition.draw()
    label = input()
    print(f"Composition {i} was given label {label}")
    composition.draw(path=f"data/{label}/{i}.png")
    composition.save(path=f"data/{label}/{i}.json")
# Out:
# Composition 0 was given label 0
# Composition 1 was given label 1
# Composition 2 was given label 0
# Composition 3 was given label 0
# Composition 4 was given label 0
# Composition 5 was given label 1
# Composition 6 was given label 0
# Composition 7 was given label 0
# Composition 8 was given label 0
# Composition 9 was given label 0
# Composition 10 was given label 0
# Composition 11 was given label 1
# Composition 12 was given label 1
# Composition 13 was given label 1
# Composition 14 was given label 1
# Composition 15 was given label 0
# Composition 16 was given label 1
# Composition 17 was given label 1
# Composition 18 was given label 1
# Composition 19 was given label 1
